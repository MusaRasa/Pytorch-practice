# %%
import torch as tr

# %%
Tensor1 = tr.tensor([[
                   [1,2,6],
                   [1,4,8],
                   [9,18,27]
                     ]])

# %%
Tensor1
# Out:
# tensor([[[ 1,  2,  6],
#          [ 1,  4,  8],
#          [ 9, 18, 27]]])

# %%
Tensor1.shape
# Out:
# torch.Size([1, 3, 3])

# %%
Tensor1.ndim
# Out:
# 3

# %% [markdown]
# ### Random tensors
# why random tensors?
# Random tensors are important because the way many neural networks learn is that they start with tensors full of random numbers and then adjust those random numbers to better represent the data.
#
#
# ``start with random numbers -> look at data -> update random number -> look at data -> update numbers``

# %%
### Create a random tensor of size (3,5)
random_tensor = tr.rand(3,5)
'Random tensor ---> \n', random_tensor
# Out:
# ('Random tensor ---> \n',
#  tensor([[0.9566, 0.1911, 0.4842, 0.5245, 0.9484],
#          [0.4901, 0.0760, 0.6258, 0.8705, 0.3668],
#          [0.8008, 0.5176, 0.5354, 0.6407, 0.7786]]))

# %%
'Number of dimenction ',random_tensor.ndim
# Out:
# ('Number of dimenction ', 2)

# %%
 Random_tensor2 = tr.rand(10,10,10)

# %%
Random_tensor2.ndim
# Out:
# 3

# %%
Random_tensor2.shape
# Out:
# torch.Size([10, 10, 10])

# %%
ten_pro = tr.tensor([[[2,3,4],[9,4,4],[0,1,0]]])
ten_pro
# Out:
# tensor([[[2, 3, 4],
#          [9, 4, 4],
#          [0, 1, 0]]])

# %%
ten_pro.ndim
# Out:
# 3

# %%
ten_pro.shape
# Out:
# torch.Size([1, 3, 3])

# %%
ten_pro
# Out:
# tensor([[[2, 3, 4],
#          [9, 4, 4],
#          [0, 1, 0]]])

# %%
# Len's index on our new tensor
ten_pro[0]
# Out:
# tensor([[2, 3, 4],
#         [9, 4, 4],
#         [0, 1, 0]])

# %%
# Let's index on the most inner bracket last dimenction
ten_pro[0][0]
# Out:
# tensor([2, 3, 4])

# %%
# You can also uof a target use ":" to select " ALL" of a target dimenction_ in this example we use 0 index
ten_pro[:,0]
# Out:
# tensor([[2, 3, 4]])

# %%
# ===>> Now we show 1 index
ten_pro[:,1]
# Out:
# tensor([[9, 4, 4]])

# %%
# === >>  Now we show 2 index 
ten_pro[:,2]
# Out:
# tensor([[0, 1, 0]])

# %%
#  In this why we can show ALl element's [:,:]
ten_pro[:,:]
# Out:
# tensor([[[2, 3, 4],
#          [9, 4, 4],
#          [0, 1, 0]]])

# %%
# Find the spcific element
