# %% [markdown]
# # MNIST with softmax
# * it is very classic and `After the Train we show improved implementation of softamx`

# %% [markdown]
# ### 1) Spacy the model

# %%
import tensorflow

# %% [markdown]
# ### 2) spacify loss and cost

# %%
model = Sequeltial(
    [
        Dense(Units = 25, activation = 'relu'),
        Dense(units = 15, activation = 'relue'),
        Dense(units = 10, activation = 'softmax')
        
    ]
    
)

# %% [markdown]
# ### 3) Train on data to minimize

# %%
from tensorflow.keras.losses import SpareCategoricalCrossentropy
model.complie(loss = SpareCategoricalCrossentropy())
model.fit(X,Y, epochs = 100)

# %% [markdown]
# #### It way's very good to implemetation of softmax

# %% [markdown]
# #### Numerical Round OFF Errors
# * if we want to calcualte 2/10000 -> we can calculate from two way
# 1. x = 2 / 10000
# 2. x = (1+1/10000) - (1-1/10000)
# * These get same results

# %%
#  Now we implement that idea to computer 
x1 = 2/10000
print(f"X1: {x1: .12f}") # Print 12 digit to the right of the decimal point
# Out:
# X1:  0.000200000000

# %%
X2 = 1+(1/10000) - (1-1/10000)
print(f"{X2: .18f}")

# %%
# Out:
# <module 'gpiozero' from 'c:\\Users\\Musa\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\gpiozero\\__init__.py'>

# %%
# MNIST (More numrically accurate)
# 1) model
import tensorflow
from tensorflow.keras import Sequentail
from tensorflow.keras.layers import Dense
model = sequentail([
    Dense(units = 25,activation='relu')
    Dense(units = 15,activation = 'relu')
    Dense(units = 10,activation = 'linear')
    
])
# 2) loss
from tensorflow.keras.losses import SparseCategoricalCrossentropy 
model.complie(loss = SparseCategoricalCrossentropy(from_logits = True))
# 3) fit
model.fit(X,Y,epochs = 100)
# predict
logits = model(X)
f_x = tf.nn.softmax(logits)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import tensorflow
#
# ModuleNotFoundError: No module named 'tensorflow'
